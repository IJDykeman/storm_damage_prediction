# %%
'''
A Convolutional Network implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits
(http://yann.lecun.com/exdb/mnist/)

Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
'''
# Out:
# '\nA Convolutional Network implementation example using TensorFlow library.\nThis example is using the MNIST database of handwritten digits\n(http://yann.lecun.com/exdb/mnist/)\n\nAuthor: Aymeric Damien\nProject: https://github.com/aymericdamien/TensorFlow-Examples/\n'

# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
        step += 1
    print "Optimization Finished!"

    # Calculate accuracy for 256 mnist test images
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.})
# Out:
# Iter 1280, Minibatch Loss= 29873.707031, Training Accuracy= 0.15625
# Iter 2560, Minibatch Loss= 413.335785, Training Accuracy= 0.12500
# Iter 3840, Minibatch Loss= 634.511780, Training Accuracy= 0.09375
# Iter 5120, Minibatch Loss= 600.061035, Training Accuracy= 0.09375
# Iter 6400, Minibatch Loss= 343.191040, Training Accuracy= 0.13281
# Iter 7680, Minibatch Loss= 205.387054, Training Accuracy= 0.13281
# Iter 8960, Minibatch Loss= 507.285400, Training Accuracy= 0.08594
# Iter 10240, Minibatch Loss= 797.164551, Training Accuracy= 0.07031
# Iter 11520, Minibatch Loss= 220.163849, Training Accuracy= 0.10156
# Iter 12800, Minibatch Loss= 294.173676, Training Accuracy= 0.12500
# Iter 14080, Minibatch Loss= 284.436707, Training Accuracy= 0.09375
# Iter 15360, Minibatch Loss= 414.171570, Training Accuracy= 0.04688
# Iter 16640, Minibatch Loss= 209.377686, Training Accuracy= 0.07812
# Iter 17920, Minibatch Loss= 268.705383, Training Accuracy= 0.11719
# Iter 19200, Minibatch Loss= 313.341492, Training Accuracy= 0.09375
# Iter 20480, Minibatch Loss= 266.645477, Training Accuracy= 0.10156
# Iter 21760, Minibatch Loss= 170.090668, Training Accuracy= 0.14062
# Iter 23040, Minibatch Loss= 572.377014, Training Accuracy= 0.10938
# Iter 24320, Minibatch Loss= 130.261856, Training Accuracy= 0.06250
# Iter 25600, Minibatch Loss= 254.760254, Training Accuracy= 0.06250
# Iter 26880, Minibatch Loss= 81.274902, Training Accuracy= 0.07812
# Iter 28160, Minibatch Loss= 68.999039, Training Accuracy= 0.07812
# Iter 29440, Minibatch Loss= 51.158371, Training Accuracy= 0.10938
# Iter 30720, Minibatch Loss= 14.965654, Training Accuracy= 0.04688
# Iter 32000, Minibatch Loss= 3.003939, Training Accuracy= 0.13281
# Iter 33280, Minibatch Loss= 2.594160, Training Accuracy= 0.09375
# Iter 34560, Minibatch Loss= 315.565186, Training Accuracy= 0.09375
# Iter 35840, Minibatch Loss= 2.951738, Training Accuracy= 0.11719
# Iter 37120, Minibatch Loss= 2.921421, Training Accuracy= 0.12500
# Iter 38400, Minibatch Loss= 195.600067, Training Accuracy= 0.09375
# Iter 39680, Minibatch Loss= 3.186493, Training Accuracy= 0.07031
# Iter 40960, Minibatch Loss= 3.109929, Training Accuracy= 0.11719
# Iter 42240, Minibatch Loss= 3.018602, Training Accuracy= 0.07812
# Iter 43520, Minibatch Loss= 2.835741, Training Accuracy= 0.10938
# Iter 44800, Minibatch Loss= 228.221191, Training Accuracy= 0.09375
# Iter 46080, Minibatch Loss= 2.807232, Training Accuracy= 0.10156
# Iter 47360, Minibatch Loss= 2.835204, Training Accuracy= 0.09375
# Iter 48640, Minibatch Loss= 2.789276, Training Accuracy= 0.14062
# Iter 49920, Minibatch Loss= 2.785580, Training Accuracy= 0.10938
# Iter 51200, Minibatch Loss= 3.971079, Training Accuracy= 0.10156
# Iter 52480, Minibatch Loss= 2.972821, Training Accuracy= 0.09375
# Iter 53760, Minibatch Loss= 2.812404, Training Accuracy= 0.12500
# Iter 55040, Minibatch Loss= 2.854825, Training Accuracy= 0.10156
# Iter 56320, Minibatch Loss= 2.723457, Training Accuracy= 0.17188
# Iter 57600, Minibatch Loss= 2.644906, Training Accuracy= 0.07031
# Iter 58880, Minibatch Loss= 3.107760, Training Accuracy= 0.09375
# Iter 60160, Minibatch Loss= 2.704495, Training Accuracy= 0.09375
# Iter 61440, Minibatch Loss= 2.563985, Training Accuracy= 0.13281
# Iter 62720, Minibatch Loss= 3.244100, Training Accuracy= 0.10156
# Iter 64000, Minibatch Loss= 36.626038, Training Accuracy= 0.05469
# Iter 65280, Minibatch Loss= 3.481591, Training Accuracy= 0.12500
# Iter 66560, Minibatch Loss= 2.752368, Training Accuracy= 0.12500
# Iter 67840, Minibatch Loss= 7.209620, Training Accuracy= 0.10156
# Iter 69120, Minibatch Loss= 3.944948, Training Accuracy= 0.11719
# Iter 70400, Minibatch Loss= 2.982612, Training Accuracy= 0.15625
# Iter 71680, Minibatch Loss= 2.811373, Training Accuracy= 0.08594
# Iter 72960, Minibatch Loss= 52.103226, Training Accuracy= 0.07812
# Iter 74240, Minibatch Loss= 2.750138, Training Accuracy= 0.11719
# Iter 75520, Minibatch Loss= 2.803451, Training Accuracy= 0.10156
# Iter 76800, Minibatch Loss= 2.867510, Training Accuracy= 0.10156
# Iter 78080, Minibatch Loss= 2.628409, Training Accuracy= 0.10156
# Iter 79360, Minibatch Loss= 33.237411, Training Accuracy= 0.06250
# Iter 80640, Minibatch Loss= 3.212472, Training Accuracy= 0.06250
# Iter 81920, Minibatch Loss= 2.871150, Training Accuracy= 0.10938
# Iter 83200, Minibatch Loss= 2.745378, Training Accuracy= 0.07812
# Iter 84480, Minibatch Loss= 3.374640, Training Accuracy= 0.08594
# Iter 85760, Minibatch Loss= 72.636093, Training Accuracy= 0.03906
# Iter 87040, Minibatch Loss= 4.019497, Training Accuracy= 0.08594
# Iter 88320, Minibatch Loss= 3.816516, Training Accuracy= 0.13281
# Iter 89600, Minibatch Loss= 2.582417, Training Accuracy= 0.11719
# Iter 90880, Minibatch Loss= 2.750203, Training Accuracy= 0.10938
# Iter 92160, Minibatch Loss= 2.485198, Training Accuracy= 0.14062
# Iter 93440, Minibatch Loss= 2.808808, Training Accuracy= 0.07031
# Iter 94720, Minibatch Loss= 2.849934, Training Accuracy= 0.09375
# Iter 96000, Minibatch Loss= 3.719129, Training Accuracy= 0.07031
# Iter 97280, Minibatch Loss= 3.857146, Training Accuracy= 0.07812
# Iter 98560, Minibatch Loss= 4.560534, Training Accuracy= 0.12500
# Iter 99840, Minibatch Loss= 2.676115, Training Accuracy= 0.07812
# Iter 101120, Minibatch Loss= 8.164484, Training Accuracy= 0.09375
# Iter 102400, Minibatch Loss= 2.548494, Training Accuracy= 0.10156
# Iter 103680, Minibatch Loss= 2.512686, Training Accuracy= 0.12500
# Iter 104960, Minibatch Loss= 2.551703, Training Accuracy= 0.12500
# Iter 106240, Minibatch Loss= 2.513274, Training Accuracy= 0.11719
# Iter 107520, Minibatch Loss= 2.641951, Training Accuracy= 0.06250
# Iter 108800, Minibatch Loss= 2.508152, Training Accuracy= 0.11719
# Iter 110080, Minibatch Loss= 2.470143, Training Accuracy= 0.13281
# Iter 111360, Minibatch Loss= 2.607093, Training Accuracy= 0.10938
# Iter 112640, Minibatch Loss= 2.648679, Training Accuracy= 0.08594
# Iter 113920, Minibatch Loss= 2.669715, Training Accuracy= 0.10156
# Iter 115200, Minibatch Loss= 2.594766, Training Accuracy= 0.14062
# Iter 116480, Minibatch Loss= 2.772580, Training Accuracy= 0.04688
# Iter 117760, Minibatch Loss= 2.678639, Training Accuracy= 0.10938
# Iter 119040, Minibatch Loss= 2.602476, Training Accuracy= 0.14844
# Iter 120320, Minibatch Loss= 2.512090, Training Accuracy= 0.07812
# Iter 121600, Minibatch Loss= 2.514959, Training Accuracy= 0.09375
# Iter 122880, Minibatch Loss= 2.543934, Training Accuracy= 0.09375
# Iter 124160, Minibatch Loss= 2.615772, Training Accuracy= 0.07031
# Iter 125440, Minibatch Loss= 2.471040, Training Accuracy= 0.14062
# Iter 126720, Minibatch Loss= 2.574551, Training Accuracy= 0.05469
# Iter 128000, Minibatch Loss= 2.465378, Training Accuracy= 0.12500
# Iter 129280, Minibatch Loss= 2.561713, Training Accuracy= 0.06250
# Iter 130560, Minibatch Loss= 2.459303, Training Accuracy= 0.09375
# Iter 131840, Minibatch Loss= 2.641234, Training Accuracy= 0.07812
# Iter 133120, Minibatch Loss= 2.540593, Training Accuracy= 0.10156
# Iter 134400, Minibatch Loss= 2.514383, Training Accuracy= 0.10938
# Iter 135680, Minibatch Loss= 2.447539, Training Accuracy= 0.11719
# Iter 136960, Minibatch Loss= 2.498113, Training Accuracy= 0.10156
# Iter 138240, Minibatch Loss= 10.956478, Training Accuracy= 0.12500
# Iter 139520, Minibatch Loss= 2.476427, Training Accuracy= 0.07031
# Iter 140800, Minibatch Loss= 2.522297, Training Accuracy= 0.05469
# Iter 142080, Minibatch Loss= 2.498300, Training Accuracy= 0.13281
# Iter 143360, Minibatch Loss= 2.380553, Training Accuracy= 0.14062
# Iter 144640, Minibatch Loss= 7.300912, Training Accuracy= 0.13281
# Iter 145920, Minibatch Loss= 2.565935, Training Accuracy= 0.07812
# Iter 147200, Minibatch Loss= 2.526732, Training Accuracy= 0.08594
# Iter 148480, Minibatch Loss= 2.379543, Training Accuracy= 0.15625
# Iter 149760, Minibatch Loss= 2.823166, Training Accuracy= 0.10156
# Iter 151040, Minibatch Loss= 2.378056, Training Accuracy= 0.10156
# Iter 152320, Minibatch Loss= 2.365346, Training Accuracy= 0.10156
# Iter 153600, Minibatch Loss= 2.488958, Training Accuracy= 0.06250
# Iter 154880, Minibatch Loss= 2.559852, Training Accuracy= 0.10156
# Iter 156160, Minibatch Loss= 2.559012, Training Accuracy= 0.10156
# Iter 157440, Minibatch Loss= 2.752713, Training Accuracy= 0.08594
# Iter 158720, Minibatch Loss= 2.598106, Training Accuracy= 0.11719
# Iter 160000, Minibatch Loss= 2.857361, Training Accuracy= 0.11719
# Iter 161280, Minibatch Loss= 2.885325, Training Accuracy= 0.06250
# Iter 162560, Minibatch Loss= 2.698266, Training Accuracy= 0.12500
# Iter 163840, Minibatch Loss= 2.987707, Training Accuracy= 0.10156
# Iter 165120, Minibatch Loss= 3.084532, Training Accuracy= 0.07812
# Iter 166400, Minibatch Loss= 3.050050, Training Accuracy= 0.10938
# Iter 167680, Minibatch Loss= 3.139878, Training Accuracy= 0.04688
# Iter 168960, Minibatch Loss= 2.823730, Training Accuracy= 0.10938
# Iter 170240, Minibatch Loss= 2.739359, Training Accuracy= 0.12500
# Iter 171520, Minibatch Loss= 3.003207, Training Accuracy= 0.10938
# Iter 172800, Minibatch Loss= 2.880576, Training Accuracy= 0.15625
# Iter 174080, Minibatch Loss= 3.363086, Training Accuracy= 0.11719
# Iter 175360, Minibatch Loss= 3.625996, Training Accuracy= 0.07812
# Iter 176640, Minibatch Loss= 3.645620, Training Accuracy= 0.09375
# Iter 177920, Minibatch Loss= 4.238986, Training Accuracy= 0.09375
# Iter 179200, Minibatch Loss= 4.049494, Training Accuracy= 0.14062
# Iter 180480, Minibatch Loss= 4.697789, Training Accuracy= 0.07031
# Iter 181760, Minibatch Loss= 2.514831, Training Accuracy= 0.14844
# Iter 183040, Minibatch Loss= 2.464794, Training Accuracy= 0.07812
# Iter 184320, Minibatch Loss= 2.391183, Training Accuracy= 0.09375
# Iter 185600, Minibatch Loss= 2.411112, Training Accuracy= 0.13281
# Iter 186880, Minibatch Loss= 2.395459, Training Accuracy= 0.10156
# Iter 188160, Minibatch Loss= 2.405812, Training Accuracy= 0.07031
# Iter 189440, Minibatch Loss= 2.398581, Training Accuracy= 0.09375
# Iter 190720, Minibatch Loss= 2.392004, Training Accuracy= 0.06250
# Iter 192000, Minibatch Loss= 2.373808, Training Accuracy= 0.14062
# Iter 193280, Minibatch Loss= 2.432308, Training Accuracy= 0.13281
# Iter 194560, Minibatch Loss= 2.351737, Training Accuracy= 0.10156
# Iter 195840, Minibatch Loss= 2.405484, Training Accuracy= 0.05469
# Iter 197120, Minibatch Loss= 2.377357, Training Accuracy= 0.08594
# Iter 198400, Minibatch Loss= 2.396782, Training Accuracy= 0.08594
# Iter 199680, Minibatch Loss= 2.372965, Training Accuracy= 0.08594
# Optimization Finished!
# Testing Accuracy: 0.171875
